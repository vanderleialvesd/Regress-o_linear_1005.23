# %% [markdown]
# <a href="https://colab.research.google.com/github/vanderleialvesd/Regress-o_linear_1005.23/blob/main/Regress%C3%A3o_linear_10_05_23_exemplo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library import
import pandas as pd
import seaborn as sn

# %%
# leitura dos dados

data = pd.read_excel("/content/teste_regressão_linear.xlsx")

# %%
print(data)
# Out:
#    Id_indivíduo  comprimento  peso
# 0             1          176    88
# 1             2          177    77
# 2             3          187    91
# 3             4          191   102
# 4             5          193   112
# 5             6          198   115
# 6             7          188   100
# 7             8          171    92
# 8             9          178    97
# 9            10          188    99

# %%
# análise de correlação

correlation = data.corr()

# %%
# plot da matriz de correlação

plot = sn.heatmap(correlation, annot = True, fmt=".2f", linewidths=.5)
plot
# Out:
# <Axes: >
